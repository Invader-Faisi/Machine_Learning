# %% [markdown]
# # Working with JSON

# %%
import pandas as pd

# %%
pd.read_json('iris.json')
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Reading json from URL

# %%
pd.read_json('http://www.floatrates.com/daily/usd.json')
# Out:
#                                        eur                            gbp  \
# code                                   EUR                            GBP
# alphaCode                              EUR                            GBP
# numericCode                            978                            826
# name                                  Euro            U.K. Pound Sterling
# rate                              0.919979                       0.790331
# date         Fri, 30 Jun 2023 23:55:01 GMT  Fri, 30 Jun 2023 23:55:01 GMT
# inverseRate                       1.086981                       1.265293
#
#                                        jpy                            aud  \
# code                                   JPY                            AUD
# alphaCode                              JPY                            AUD
# numericCode                            392                            036
# name                          Japanese Yen              Australian Dollar
# ...

# %% [markdown]
# # Working with SQL Data

# %%
import mysql.connector
conn = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world')

# %%
data = pd.read_sql_query('SELECT * FROM countries', conn)
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_5736\1593806832.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query('SELECT * FROM countries', conn)

# %%
data
# Out:
#       id                       name iso3 iso2 phonecode      capital currency  \
# 0      1                Afghanistan  AFG   AF        93        Kabul      AFN
# 1      2              Aland Islands  ALA   AX   +358-18    Mariehamn      EUR
# 2      3                    Albania  ALB   AL       355       Tirana      ALL
# 3      4                    Algeria  DZA   DZ       213      Algiers      DZD
# 4      5             American Samoa  ASM   AS    +1-684    Pago Pago      USD
# ..   ...                        ...  ...  ...       ...          ...      ...
# 245  246                     Zambia  ZMB   ZM       260       Lusaka      ZMW
# 246  247                   Zimbabwe  ZWE   ZW       263       Harare      ZWL
# 247  248                     Kosovo  XKX   XK       383     Pristina      EUR
# 248  249                    Curaçao  CUW   CW       599   Willemstad      ANG
# 249  250  Sint Maarten (Dutch part)  SXM   SX      1721  Philipsburg      ANG
#
# ...
